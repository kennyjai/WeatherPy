# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key from api_keys.py file
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Incorporate time to get today's date
date = time.strftime("%D")

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
# Randomly select at least 500 unique cities based on lat and lng
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795'

# %%
# Create a pandas dataframe of all the randomly generated cities
df = pd.DataFrame(cities)

df = df.rename(columns={0:"City"})

# Add additional columns that we will use to analyze the temperature closer to the equator
df["Cloudiness"] = ""
df["Country"] = ""
df["Date"] = ""
df["Humidity"] = ""
df["Lat"] = ""
df["Lng"] = ""
df["Max Temp"] = ""
df["Wind Speed"] = ""

df.head()
# Out:
#         City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0    mataura
# 1   victoria
# 2  jamestown
# 3    rikitea
# 4   tasiilaq

# %%
# Use iterows to iterate through pandas dataframe
for index, row in df.iterrows():
    
    # Get the city name from the dataframe
    city = row["City"]
    
    try:
        # Assemble url and make API request
        response = requests.get(url + "&q=" + city).json()
        
        # Print index number and city name followed with the json url for the searched city
        print(f'Processing Record {index} | {city}')
        print(f'{url}&q={city.replace(" ","%20")}') # replace spaces with '%20' to get proper url formatting
        
        # parse through data and append results into the dataframe
        df.loc[index, 'Cloudiness'] = response['clouds']['all']
        df.loc[index, 'Country'] = response['sys']['country']
        df.loc[index, 'Date'] = response['dt']
        df.loc[index, 'Humidity'] = response['main']['humidity']
        df.loc[index, 'Lat'] = response['coord']['lat']
        df.loc[index, 'Lng'] = response['coord']['lon']
        df.loc[index, 'Max Temp'] = response['main']['temp_max']
        df.loc[index, 'Wind Speed'] = response['wind']['speed']
        
    except:
        # if data is missing, leave as empty and skip to next one
        df.loc[index, 'Cloudiness'] = None
        df.loc[index, 'Country'] = None
        df.loc[index, 'Date'] = None
        df.loc[index, 'Humidity'] = None
        df.loc[index, 'Lat'] = None
        df.loc[index, 'Lng'] = None
        df.loc[index, 'Max Temp'] = None
        df.loc[index, 'Wind Speed'] = None
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Processing Record 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mataura
# ------------
# Processing Record 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=victoria
# ------------
# Processing Record 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jamestown
# ------------
# Processing Record 3 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=rikitea
# ------------
# Processing Record 4 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tasiilaq
# ------------
# Processing Record 5 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bredasdorp
# ------------
# Processing Record 6 | kankon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kankon
# ------------
# Processing Record 7 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint-philippe
# ------------
# Processing Record 8 | iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=iquitos
# ------------
# Processing Record 9 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=maragogi
# ------------
# Processing Record 10 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kodiak
# ------------
# Processing Record 11 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=samarai
# ------------
# Processing Record 12 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ribeira%20grande
# ------------
# Processing Record 13 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=klaksvik
# ------------
# Processing Record 14 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mangrol
# ------------
# Processing Record 15 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cherskiy
# ------------
# Processing Record 16 | tarudant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tarudant
# Missing field/result... skipping.
# ------------
# Processing Record 17 | itaqui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=itaqui
# ------------
# Processing Record 18 | vitim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vitim
# ------------
# Processing Record 19 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=albany
# ------------
# Processing Record 20 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=coihaique
# ------------
# Processing Record 21 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=punta%20arenas
# ------------
# Processing Record 22 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bluff
# ------------
# Processing Record 23 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=salinopolis
# ------------
# Processing Record 24 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=comodoro%20rivadavia
# ------------
# Processing Record 25 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=chokurdakh
# ------------
# Processing Record 26 | libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=libertador%20general%20san%20martin
# ------------
# Processing Record 27 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port%20elizabeth
# ------------
# Processing Record 28 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=upernavik
# ------------
# Processing Record 29 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cabo%20san%20lucas
# ------------
# Processing Record 30 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ushuaia
# ------------
# Processing Record 31 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port%20alfred
# ------------
# Processing Record 32 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=puerto%20ayora
# ------------
# Processing Record 33 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tautira
# ------------
# Processing Record 34 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=buala
# ------------
# Processing Record 35 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=dwarka
# ------------
# Processing Record 36 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=barrow
# ------------
# Processing Record 37 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=palauig
# ------------
# Processing Record 38 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hilo
# ------------
# Processing Record 39 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hermanus
# ------------
# Processing Record 40 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=beyneu
# ------------
# Processing Record 41 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=dongsheng
# ------------
# Processing Record 42 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=moron
# ------------
# Processing Record 43 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=batticaloa
# ------------
# Processing Record 44 | la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=la%20palma
# ------------
# Processing Record 45 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saryshagan
# Missing field/result... skipping.
# ------------
# Processing Record 46 | uvat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=uvat
# ------------
# Processing Record 47 | businga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=businga
# ------------
# Processing Record 48 | aragarcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=aragarcas
# ------------
# Processing Record 49 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=busselton
# ------------
# Processing Record 50 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=illoqqortoormiut
# Missing field/result... skipping.
# ------------
# Processing Record 51 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=thompson
# ------------
# Processing Record 52 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=butaritari
# ------------
# Processing Record 53 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mys%20shmidta
# Missing field/result... skipping.
# ------------
# Processing Record 54 | inongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=inongo
# ------------
# Processing Record 55 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=xining
# ------------
# Processing Record 56 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hambantota
# ------------
# Processing Record 57 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saldanha
# ------------
# Processing Record 58 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=taolanaro
# Missing field/result... skipping.
# ------------
# Processing Record 59 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=qaanaaq
# ------------
# Processing Record 60 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=faanui
# ------------
# Processing Record 61 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=wonthaggi
# ------------
# Processing Record 62 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=huilong
# ------------
# Processing Record 63 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mecca
# ------------
# Processing Record 64 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cape%20town
# ------------
# Processing Record 65 | poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=poya
# ------------
# Processing Record 66 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kahului
# ------------
# Processing Record 67 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=igarka
# ------------
# Processing Record 68 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=new%20norfolk
# ------------
# Processing Record 69 | canico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=canico
# ------------
# Processing Record 70 | shakiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=shakiso
# ------------
# Processing Record 71 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nioro
# ------------
# Processing Record 72 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=souillac
# ------------
# Processing Record 73 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sentyabrskiy
# Missing field/result... skipping.
# ------------
# Processing Record 74 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lompoc
# ------------
# Processing Record 75 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tura
# ------------
# Processing Record 76 | chase
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=chase
# ------------
# Processing Record 77 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=georgetown
# ------------
# Processing Record 78 | sovetskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sovetskoye
# ------------
# Processing Record 79 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=komsomolskiy
# ------------
# Processing Record 80 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=basco
# ------------
# Processing Record 81 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=fortuna
# ------------
# Processing Record 82 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kruisfontein
# ------------
# Processing Record 83 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint-augustin
# ------------
# Processing Record 84 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yellowknife
# ------------
# Processing Record 85 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=torbay
# ------------
# Processing Record 86 | fershampenuaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=fershampenuaz
# ------------
# Processing Record 87 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vaini
# ------------
# Processing Record 88 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=leningradskiy
# ------------
# Processing Record 89 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sinnamary
# ------------
# Processing Record 90 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=louisbourg
# Missing field/result... skipping.
# ------------
# Processing Record 91 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lagoa
# ------------
# Processing Record 92 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kapaa
# ------------
# Processing Record 93 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nelson%20bay
# ------------
# Processing Record 94 | pedasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pedasi
# ------------
# Processing Record 95 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint%20george
# ------------
# Processing Record 96 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=provideniya
# ------------
# Processing Record 97 | mangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mangai
# ------------
# Processing Record 98 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=coquimbo
# ------------
# Processing Record 99 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hobart
# ------------
# Processing Record 100 | yverdon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yverdon
# Missing field/result... skipping.
# ------------
# Processing Record 101 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=husavik
# ------------
# Processing Record 102 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tuktoyaktuk
# ------------
# Processing Record 103 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=khatanga
# ------------
# Processing Record 104 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saskylakh
# ------------
# Processing Record 105 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=adrar
# ------------
# Processing Record 106 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=teya
# ------------
# Processing Record 107 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=maceio
# ------------
# Processing Record 108 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mar%20del%20plata
# ------------
# Processing Record 109 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=avera
# ------------
# Processing Record 110 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ancud
# ------------
# Processing Record 111 | muscat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=muscat
# ------------
# Processing Record 112 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=grand%20river%20south%20east
# Missing field/result... skipping.
# ------------
# Processing Record 113 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=narsaq
# ------------
# Processing Record 114 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=manta
# ------------
# Processing Record 115 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=airai
# ------------
# Processing Record 116 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sovetskiy
# ------------
# Processing Record 117 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nikolskoye
# ------------
# Processing Record 118 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=arraial%20do%20cabo
# ------------
# Processing Record 119 | sosnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sosnogorsk
# ------------
# Processing Record 120 | krasnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=krasnogorsk
# ------------
# Processing Record 121 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=aklavik
# ------------
# Processing Record 122 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=geraldton
# ------------
# Processing Record 123 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kloulklubed
# ------------
# Processing Record 124 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nizhneyansk
# Missing field/result... skipping.
# ------------
# Processing Record 125 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ayan
# ------------
# Processing Record 126 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kiama
# ------------
# Processing Record 127 | borzya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=borzya
# ------------
# Processing Record 128 | sucua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sucua
# ------------
# Processing Record 129 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=norman%20wells
# ------------
# Processing Record 130 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vila
# ------------
# Processing Record 131 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hirara
# ------------
# Processing Record 132 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tiksi
# ------------
# Processing Record 133 | high rock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=high%20rock
# ------------
# Processing Record 134 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vila%20franca%20do%20campo
# ------------
# Processing Record 135 | nivala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nivala
# ------------
# Processing Record 136 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tessalit
# ------------
# Processing Record 137 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=anadyr
# ------------
# Processing Record 138 | arroyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=arroyo
# ------------
# Processing Record 139 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=krasnoselkup
# Missing field/result... skipping.
# ------------
# Processing Record 140 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vao
# ------------
# Processing Record 141 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=luderitz
# ------------
# Processing Record 142 | barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=barranca
# ------------
# Processing Record 143 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kaitangata
# ------------
# Processing Record 144 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kattivakkam
# ------------
# Processing Record 145 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=flin%20flon
# ------------
# Processing Record 146 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vanimo
# ------------
# Processing Record 147 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=buin
# ------------
# Processing Record 148 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=longyearbyen
# ------------
# Processing Record 149 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port%20keats
# ------------
# Processing Record 150 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=alice%20springs
# ------------
# Processing Record 151 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=constitucion
# ------------
# Processing Record 152 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=aykhal
# ------------
# Processing Record 153 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lasa
# ------------
# Processing Record 154 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saleaula
# Missing field/result... skipping.
# ------------
# Processing Record 155 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vestmannaeyjar
# ------------
# Processing Record 156 | jhang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jhang
# ------------
# Processing Record 157 | antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=antsohihy
# ------------
# Processing Record 158 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=dikson
# ------------
# Processing Record 159 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=asau
# Missing field/result... skipping.
# ------------
# Processing Record 160 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pilar
# ------------
# Processing Record 161 | santa eulalia del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=santa%20eulalia%20del%20rio
# Missing field/result... skipping.
# ------------
# Processing Record 162 | simpang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=simpang
# ------------
# Processing Record 163 | iskilip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=iskilip
# ------------
# Processing Record 164 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mitu
# ------------
# Processing Record 165 | chupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=chupa
# ------------
# Processing Record 166 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=east%20london
# ------------
# Processing Record 167 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cayenne
# ------------
# Processing Record 168 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bethel
# ------------
# Processing Record 169 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vardo
# ------------
# Processing Record 170 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lakatoro
# ------------
# Processing Record 171 | fairfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=fairfield
# ------------
# Processing Record 172 | luban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=luban
# ------------
# Processing Record 173 | buchmany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=buchmany
# ------------
# Processing Record 174 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=phan%20thiet
# ------------
# Processing Record 175 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=namatanai
# ------------
# Processing Record 176 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kununurra
# ------------
# Processing Record 177 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mahebourg
# ------------
# Processing Record 178 | karaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=karaton
# ------------
# Processing Record 179 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=goderich
# ------------
# Processing Record 180 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ballina
# ------------
# Processing Record 181 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=beloha
# ------------
# Processing Record 182 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hithadhoo
# ------------
# Processing Record 183 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ketchikan
# ------------
# Processing Record 184 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=warqla
# Missing field/result... skipping.
# ------------
# Processing Record 185 | wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=wuwei
# ------------
# Processing Record 186 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pangai
# ------------
# Processing Record 187 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=atuona
# ------------
# Processing Record 188 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kavieng
# ------------
# Processing Record 189 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=oranjestad
# ------------
# Processing Record 190 | kargil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kargil
# ------------
# Processing Record 191 | bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bosaso
# ------------
# Processing Record 192 | san miguel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=san%20miguel
# ------------
# Processing Record 193 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=barentsburg
# Missing field/result... skipping.
# ------------
# Processing Record 194 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port%20hedland
# ------------
# Processing Record 195 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=barawe
# Missing field/result... skipping.
# ------------
# Processing Record 196 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=champerico
# ------------
# Processing Record 197 | melito di porto salvo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=melito%20di%20porto%20salvo
# ------------
# Processing Record 198 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jumla
# ------------
# Processing Record 199 | severomuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=severomuysk
# ------------
# Processing Record 200 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tuatapere
# ------------
# Processing Record 201 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=grand%20gaube
# ------------
# Processing Record 202 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lorengau
# ------------
# Processing Record 203 | yarim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yarim
# ------------
# Processing Record 204 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=banda%20aceh
# ------------
# Processing Record 205 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ilulissat
# ------------
# Processing Record 206 | jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jardim
# ------------
# Processing Record 207 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=te%20anau
# ------------
# Processing Record 208 | cambridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cambridge
# ------------
# Processing Record 209 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=amahai
# ------------
# Processing Record 210 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=carnarvon
# ------------
# Processing Record 211 | goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=goundam
# ------------
# Processing Record 212 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ojinaga
# ------------
# Processing Record 213 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ponta%20do%20sol
# ------------
# Processing Record 214 | dharan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=dharan
# ------------
# Processing Record 215 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kaka
# ------------
# Processing Record 216 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bengkulu
# Missing field/result... skipping.
# ------------
# Processing Record 217 | san matias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=san%20matias
# ------------
# Processing Record 218 | baracoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=baracoa
# ------------
# Processing Record 219 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bilibino
# ------------
# Processing Record 220 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yulara
# ------------
# Processing Record 221 | odiongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=odiongan
# ------------
# Processing Record 222 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sitka
# ------------
# Processing Record 223 | abalak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=abalak
# ------------
# Processing Record 224 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pangnirtung
# ------------
# Processing Record 225 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=broome
# ------------
# Processing Record 226 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=belushya%20guba
# Missing field/result... skipping.
# ------------
# Processing Record 227 | guanare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=guanare
# ------------
# Processing Record 228 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=eureka
# ------------
# Processing Record 229 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=panaba
# ------------
# Processing Record 230 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sibolga
# ------------
# Processing Record 231 | kholm-zhirkovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kholm-zhirkovskiy
# ------------
# Processing Record 232 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=rio%20gallegos
# ------------
# Processing Record 233 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=north%20bend
# ------------
# Processing Record 234 | el alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=el%20alto
# ------------
# Processing Record 235 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mugur-aksy
# ------------
# Processing Record 236 | kletnya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kletnya
# ------------
# Processing Record 237 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=avarua
# ------------
# Processing Record 238 | ubinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ubinskoye
# ------------
# Processing Record 239 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=antofagasta
# ------------
# Processing Record 240 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lavrentiya
# ------------
# Processing Record 241 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=santa%20rosa
# ------------
# Processing Record 242 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=svetlogorsk
# ------------
# Processing Record 243 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kutum
# ------------
# Processing Record 244 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=praia%20da%20vitoria
# ------------
# Processing Record 245 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=rawson
# ------------
# Processing Record 246 | itambacuri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=itambacuri
# ------------
# Processing Record 247 | muriwai beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=muriwai%20beach
# ------------
# Processing Record 248 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pevek
# ------------
# Processing Record 249 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=solovetskiy
# Missing field/result... skipping.
# ------------
# Processing Record 250 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=college
# ------------
# Processing Record 251 | sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sao%20miguel%20do%20araguaia
# ------------
# Processing Record 252 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=gizo
# ------------
# Processing Record 253 | bayji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bayji
# ------------
# Processing Record 254 | shwebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=shwebo
# ------------
# Processing Record 255 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cidreira
# ------------
# Processing Record 256 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pitimbu
# ------------
# Processing Record 257 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=necochea
# ------------
# Processing Record 258 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=atar
# ------------
# Processing Record 259 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=qaqortoq
# ------------
# Processing Record 260 | isperih
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=isperih
# ------------
# Processing Record 261 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bilma
# ------------
# Processing Record 262 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hamilton
# ------------
# Processing Record 263 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=luganville
# ------------
# Processing Record 264 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=alofi
# ------------
# Processing Record 265 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nantucket
# ------------
# Processing Record 266 | pueblo nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pueblo%20nuevo
# ------------
# Processing Record 267 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ambilobe
# ------------
# Processing Record 268 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=qasigiannguit
# ------------
# Processing Record 269 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=castro
# ------------
# Processing Record 270 | esfahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=esfahan
# ------------
# Processing Record 271 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=chapais
# ------------
# Processing Record 272 | zomba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=zomba
# ------------
# Processing Record 273 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=katsuura
# ------------
# Processing Record 274 | genhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=genhe
# ------------
# Processing Record 275 | merritt island
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=merritt%20island
# ------------
# Processing Record 276 | koson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=koson
# ------------
# Processing Record 277 | bachaquero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bachaquero
# ------------
# Processing Record 278 | jamshedpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jamshedpur
# ------------
# Processing Record 279 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bargal
# Missing field/result... skipping.
# ------------
# Processing Record 280 | vicuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=vicuna
# Missing field/result... skipping.
# ------------
# Processing Record 281 | twin falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=twin%20falls
# ------------
# Processing Record 282 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=paamiut
# ------------
# Processing Record 283 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hami
# ------------
# Processing Record 284 | malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=malanje
# ------------
# Processing Record 285 | wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=wakkanai
# ------------
# Processing Record 286 | peterhead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=peterhead
# ------------
# Processing Record 287 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lebu
# ------------
# Processing Record 288 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=touros
# ------------
# Processing Record 289 | bacuit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bacuit
# Missing field/result... skipping.
# ------------
# Processing Record 290 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=nouadhibou
# ------------
# Processing Record 291 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hasaki
# ------------
# Processing Record 292 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=aflu
# Missing field/result... skipping.
# ------------
# Processing Record 293 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=esperance
# ------------
# Processing Record 294 | naustdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=naustdal
# ------------
# Processing Record 295 | flic en flac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=flic%20en%20flac
# ------------
# Processing Record 296 | akhmeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=akhmeta
# ------------
# Processing Record 297 | dolinsk
# ...
# ------------
# Processing Record 509 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=namibe
# ------------
# Processing Record 510 | irece
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=irece
# ------------
# Processing Record 511 | moroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=moroni
# ------------
# Processing Record 512 | simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=simao
# ------------
# Processing Record 513 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=taltal
# ------------
# Processing Record 514 | portage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=portage
# ------------
# Processing Record 515 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=poronaysk
# ------------
# Processing Record 516 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=darhan
# ------------
# Processing Record 517 | leonidovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=leonidovo
# ------------
# Processing Record 518 | lappeenranta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lappeenranta
# ------------
# Processing Record 519 | voh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=voh
# ------------
# Processing Record 520 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=abha
# ------------
# Processing Record 521 | leua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=leua
# ------------
# Processing Record 522 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sorland
# ------------
# Processing Record 523 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bubaque
# ------------
# Processing Record 524 | shiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=shiraz
# ------------
# Processing Record 525 | kwekwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kwekwe
# ------------
# Processing Record 526 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hobyo
# ------------
# Processing Record 527 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cap%20malheureux
# ------------
# Processing Record 528 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=samusu
# Missing field/result... skipping.
# ------------
# Processing Record 529 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=naze
# ------------
# Processing Record 530 | beruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=beruwala
# ------------
# Processing Record 531 | beaver dam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=beaver%20dam
# ------------
# Processing Record 532 | jingdezhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jingdezhen
# ------------
# Processing Record 533 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ranong
# ------------
# Processing Record 534 | jinchengjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=jinchengjiang
# Missing field/result... skipping.
# ------------
# Processing Record 535 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=talnakh
# ------------
# Processing Record 536 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=akyab
# Missing field/result... skipping.
# ------------
# Processing Record 537 | chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=chabahar
# ------------
# Processing Record 538 | bassila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bassila
# ------------
# Processing Record 539 | mbulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mbulu
# ------------
# Processing Record 540 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kungurtug
# ------------
# Processing Record 541 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=najran
# ------------
# Processing Record 542 | holzminden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=holzminden
# ------------
# Processing Record 543 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=juneau
# ------------
# Processing Record 544 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mezen
# ------------
# Processing Record 545 | cerritos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=cerritos
# ------------
# Processing Record 546 | yalutorovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yalutorovsk
# ------------
# Processing Record 547 | tara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tara
# ------------
# Processing Record 548 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=sinegorye
# ------------
# Processing Record 549 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=wulanhaote
# Missing field/result... skipping.
# ------------
# Processing Record 550 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ambon
# ------------
# Processing Record 551 | ha giang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ha%20giang
# ------------
# Processing Record 552 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=verkhnyaya%20inta
# ------------
# Processing Record 553 | usvyaty
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=usvyaty
# ------------
# Processing Record 554 | clocolan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=clocolan
# ------------
# Processing Record 555 | moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=moranbah
# ------------
# Processing Record 556 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tiarei
# ------------
# Processing Record 557 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=zyryanka
# ------------
# Processing Record 558 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ndele
# Missing field/result... skipping.
# ------------
# Processing Record 559 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint%20anthony
# ------------
# Processing Record 560 | artyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=artyk
# Missing field/result... skipping.
# ------------
# Processing Record 561 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=laguna
# ------------
# Processing Record 562 | abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=abnub
# ------------
# Processing Record 563 | palkaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=palkaka
# Missing field/result... skipping.
# ------------
# Processing Record 564 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=shenjiamen
# ------------
# Processing Record 565 | eucaliptus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=eucaliptus
# ------------
# Processing Record 566 | bakchar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bakchar
# ------------
# Processing Record 567 | veliki preslav
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=veliki%20preslav
# ------------
# Processing Record 568 | x-can
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=x-can
# Missing field/result... skipping.
# ------------
# Processing Record 569 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ornskoldsvik
# ------------
# Processing Record 570 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=los%20llanos%20de%20aridane
# ------------
# Processing Record 571 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint-joseph
# ------------
# Processing Record 572 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=mehamn
# ------------
# Processing Record 573 | bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bafoulabe
# ------------
# Processing Record 574 | graham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=graham
# ------------
# Processing Record 575 | druzhnaya gorka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=druzhnaya%20gorka
# ------------
# Processing Record 576 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kamenka
# ------------
# Processing Record 577 | ahumada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ahumada
# Missing field/result... skipping.
# ------------
# Processing Record 578 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=skalistyy
# Missing field/result... skipping.
# ------------
# Processing Record 579 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ponta%20delgada
# ------------
# Processing Record 580 | tayshet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=tayshet
# ------------
# Processing Record 581 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=hofn
# ------------
# Processing Record 582 | lae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=lae
# ------------
# Processing Record 583 | niigata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=niigata
# ------------
# Processing Record 584 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=beringovskiy
# ------------
# Processing Record 585 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pacifica
# ------------
# Processing Record 586 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=san%20cristobal
# ------------
# Processing Record 587 | pombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pombia
# ------------
# Processing Record 588 | kato milea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=kato%20milea
# ------------
# Processing Record 589 | devils lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=devils%20lake
# ------------
# Processing Record 590 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port-cartier
# ------------
# Processing Record 591 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=paita
# ------------
# Processing Record 592 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ola
# ------------
# Processing Record 593 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=bayir
# ------------
# Processing Record 594 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=pangkalanbuun
# ------------
# Processing Record 595 | french harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=french%20harbor
# ------------
# Processing Record 596 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=saint-pierre
# ------------
# Processing Record 597 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=solnechnyy
# ------------
# Processing Record 598 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=port%20moresby
# ------------
# Processing Record 599 | belchatow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=belchatow
# ------------
# Processing Record 600 | oro valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=oro%20valley
# ------------
# Processing Record 601 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=ust-kuyga
# ------------
# Processing Record 602 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=portland
# ------------
# Processing Record 603 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=the%20valley
# ------------
# Processing Record 604 | yurimaguas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=yurimaguas
# ------------
# Processing Record 605 | umea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=umea
# ------------
# Processing Record 606 | snasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0696b5800f687c6de537721dc2dd795&q=snasa
# ------------

# %%
# preview data that we received
df.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0    mataura         92      NZ  1532125347       72 -46.19  168.86    47.68
# 1   victoria         75      BN  1532124000       88   5.28  115.24     80.6
# 2  jamestown         92      AU  1532125196       93 -33.21   138.6    37.69
# 3    rikitea         92      PF  1532125348       99 -23.12 -134.97    74.59
# 4   tasiilaq         12      GL  1532123400       81  65.61  -37.64     42.8
#
#   Wind Speed
# 0       5.61
# 1       1.12
# 2       4.94
# 3      14.12
# 4       6.93

# %%
# verify we have same amount of data for the cities
len(df)
# Out:
# 607

# %% [markdown]
# ## Latitude vs Temperature

# %%
# Creating x and y axis of our plot
x_axis = df['Lat']
y_axis = df['Max Temp']

plt.scatter(x_axis,y_axis,marker='o',color='darkblue',edgecolors='black',s=15)

# plot title, x and y labels, show grid
plt.title(f"City Latitude vs. Max Temperature {date}",fontweight='bold')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# save figure
plt.savefig("output_data/lat_vs_temperature.png")

# show figure
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity

# %%
# Creating x and y axis of our plot
x_axis = df['Lat']
y_axis = df['Humidity']

plt.scatter(x_axis,y_axis,marker='o',color='darkblue',edgecolors='black',s=15)

# plot title, x and y labels, show grid
plt.title(f"City Latitude vs. Humidity {date}",fontweight='bold')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# save figure
plt.savefig("output_data/lat_vs_humidity.png")

# show figure
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness

# %%
# Creating x and y axis of our plot
x_axis = df['Lat']
y_axis = df['Cloudiness']

plt.scatter(x_axis,y_axis,marker='o',color='darkblue',edgecolors='black',s=15)

# plot title, x and y labels, show grid
plt.title(f"City Latitude vs. Cloudiness {date}",fontweight='bold')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# save figure
plt.savefig("output_data/lat_vs_cloudiness.png")

# show figure
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed

# %%
# Creating x and y axis of our plot
x_axis = df['Lat']
y_axis = df['Wind Speed']

plt.scatter(x_axis,y_axis,marker='o',color='darkblue',edgecolors='black',s=15)

# plot title, x and y labels, show grid
plt.title(f"City Latitude vs. Wind Speed {date}",fontweight='bold')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

# save figure
plt.savefig("output_data/lat_vs_wind.png")

# show figure
plt.show()

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
df.to_csv(output_data_file, encoding="utf-8", index=False)

# %% [markdown]
# ## Longitude vs Latitude (Bonus Content)

# %%
# Creating extra plot to view the coordinates of the cities in our dataframe to visualize how they align
x_axis = df['Lng']
y_axis = df['Lat']

plt.scatter(x_axis,y_axis,marker='o',color='darkblue',edgecolors='black',s=15)

# plot title, x and y labels, show grid
plt.title(f"Longitude vs Latitude {date}",fontweight='bold')
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid()

# save figure
plt.savefig("output_data/lng_vs_lat.png")

# show figure
plt.show()

# %% [markdown]
# ## Analysis

# %% [markdown]
# In this project, we are attempting to prove that the weather is warmer as we approach the equator. When analyzing the Latitude vs Max Temperature data, we can see from the plot that the temperature does indeed get higher as its closer to the equator (latitude of 0). When you analayze that scatter plot, you can see all the points plot in the shape of an arch since the max temperature is higher for cities closest to the equator and is lower for cities further away from the equator.
#
# Another trend that we can see that supports our argument is by observing the humidity. When looking at the plot for Latitude vs Humidity, we can see that although cities with all ranges of latitudes can all have a high humidity percentage, the cities that have the lower humidity percentages are typically the cities that are further away from the equator.
#
# An interesting trend that we can observe from both the Cloudiness and Wind Speed plots however, is that there doesn't appear to be much of a correlation between Latitude and Cloudiness/Wind Speed. Cloudiness appears to be be dispursed sporadically independent of latitude. With Wind Speed, one can suggest that the cities with higher wind speeds are typically observed further from the equator but after trying different sample runs, its difficult to conclude that higher wind speeds are dependent on the latitude.
#
# Overall, given the data and plots that we've produced here, we can confidentally say that the weather does get warmer as we approach the equator.
